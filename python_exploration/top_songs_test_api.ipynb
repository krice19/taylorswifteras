# %%
import spotipy
import spotipy.util as util
from config import client_id, client_secret
import json


redirect_uri = 'http://localhost:7777/callback'
scope = 'user-top-read'


token = util.prompt_for_user_token(
                                   scope=scope, 
                                   client_id=client_id,   
                                   client_secret=client_secret,     
                                   redirect_uri=redirect_uri)

# %%
sp = spotipy.Spotify(auth=token)

# %%
top_tracks = sp.current_user_top_tracks(limit=50,time_range='long_term')

# %%
top_tracks
# Out:
# {'items': [{'album': {'album_type': 'COMPILATION',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YWJ1WjMkBCB1X3QOJ1Wdn'},
#       'href': 'https://api.spotify.com/v1/artists/1YWJ1WjMkBCB1X3QOJ1Wdn',
#       'id': '1YWJ1WjMkBCB1X3QOJ1Wdn',
#       'name': 'Cast of High School Musical: The Musical: The Series',
#       'type': 'artist',
#       'uri': 'spotify:artist:1YWJ1WjMkBCB1X3QOJ1Wdn'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3xvaSlT4xsyk6lY1ESOspO'},
#       'href': 'https://api.spotify.com/v1/artists/3xvaSlT4xsyk6lY1ESOspO',
#       'id': '3xvaSlT4xsyk6lY1ESOspO',
#       'name': 'Disney',
#       'type': 'artist',
#       'uri': 'spotify:artist:3xvaSlT4xsyk6lY1ESOspO'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4GgojLZOPRu8MdUVmjNRSI'},
#     'href': 'https://api.spotify.com/v1/albums/4GgojLZOPRu8MdUVmjNRSI',
#     'id': '4GgojLZOPRu8MdUVmjNRSI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273103b7e52b6a1b74035385876',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02103b7e52b6a1b74035385876',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851103b7e52b6a1b74035385876',
#       'width': 64}],
#     'name': 'High School Musical: The Musical: The Series (Original Soundtrack)',
#     'release_date': '2020-01-10',
#     'release_date_precision': 'day',
#     'total_tracks': 41,
#     'type': 'album',
#     'uri': 'spotify:album:4GgojLZOPRu8MdUVmjNRSI'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#      'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#      'id': '1McMsnEElThX1knmY4oliG',
#      'name': 'Olivia Rodrigo',
#      'type': 'artist',
#      'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3xvaSlT4xsyk6lY1ESOspO'},
#      'href': 'https://api.spotify.com/v1/artists/3xvaSlT4xsyk6lY1ESOspO',
#      'id': '3xvaSlT4xsyk6lY1ESOspO',
#      'name': 'Disney',
#      'type': 'artist',
#      'uri': 'spotify:artist:3xvaSlT4xsyk6lY1ESOspO'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 177322,
#    'explicit': False,
#    'external_ids': {'isrc': 'USWD11995182'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1v6svH1Fyx9C1nIt1mA2DT'},
#    'href': 'https://api.spotify.com/v1/tracks/1v6svH1Fyx9C1nIt1mA2DT',
#    'id': '1v6svH1Fyx9C1nIt1mA2DT',
#    'is_local': False,
#    'name': 'All I Want',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/9cb45032dcc3e596260cefa3a62956c89e699983?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:1v6svH1Fyx9C1nIt1mA2DT'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6DEjYFkNZh67HP7R9PSZvv'},
#     'href': 'https://api.spotify.com/v1/albums/6DEjYFkNZh67HP7R9PSZvv',
#     'id': '6DEjYFkNZh67HP7R9PSZvv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273da5d5aeeabacacc1263c0f4b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02da5d5aeeabacacc1263c0f4b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851da5d5aeeabacacc1263c0f4b',
#       'width': 64}],
#     'name': 'reputation',
#     'release_date': '2017-11-10',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:6DEjYFkNZh67HP7R9PSZvv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 233626,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCJY1750010'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0VE4kBnHJUgtMf0dy6DRmW'},
#    'href': 'https://api.spotify.com/v1/tracks/0VE4kBnHJUgtMf0dy6DRmW',
#    'id': '0VE4kBnHJUgtMf0dy6DRmW',
#    'is_local': False,
#    'name': 'Getaway Car',
#    'popularity': 88,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3b7c75273822da52311019692f2db7b933d1b74f?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:0VE4kBnHJUgtMf0dy6DRmW'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#     'href': 'https://api.spotify.com/v1/albums/1NAmidJlEaVgA3MpcPFYGq',
#     'id': '1NAmidJlEaVgA3MpcPFYGq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e787cffec20aa2a396a61647',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e787cffec20aa2a396a61647',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e787cffec20aa2a396a61647',
#       'width': 64}],
#     'name': 'Lover',
#     'release_date': '2019-08-23',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:1NAmidJlEaVgA3MpcPFYGq'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 178426,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG11901472'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1BxfuPKGuaTgP7aM0Bbdwr'},
#    'href': 'https://api.spotify.com/v1/tracks/1BxfuPKGuaTgP7aM0Bbdwr',
#    'id': '1BxfuPKGuaTgP7aM0Bbdwr',
#    'is_local': False,
#    'name': 'Cruel Summer',
#    'popularity': 98,
#    'preview_url': 'https://p.scdn.co/mp3-preview/dba15da5409f3c808022cf927c0ff8581f717aa4?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:1BxfuPKGuaTgP7aM0Bbdwr'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#       'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#       'id': '1McMsnEElThX1knmY4oliG',
#       'name': 'Olivia Rodrigo',
#       'type': 'artist',
#       'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6s84u2TUpR3wdUv4NgKA2j'},
#     'href': 'https://api.spotify.com/v1/albums/6s84u2TUpR3wdUv4NgKA2j',
#     'id': '6s84u2TUpR3wdUv4NgKA2j',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a91c10fe9472d9bd89802e5a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a91c10fe9472d9bd89802e5a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a91c10fe9472d9bd89802e5a',
#       'width': 64}],
#     'name': 'SOUR',
#     'release_date': '2021-05-21',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6s84u2TUpR3wdUv4NgKA2j'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#      'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#      'id': '1McMsnEElThX1knmY4oliG',
#      'name': 'Olivia Rodrigo',
#      'type': 'artist',
#      'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 178146,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG12101245'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4ZtFanR9U6ndgddUvNcjcG'},
#    'href': 'https://api.spotify.com/v1/tracks/4ZtFanR9U6ndgddUvNcjcG',
#    'id': '4ZtFanR9U6ndgddUvNcjcG',
#    'is_local': False,
#    'name': 'good 4 u',
#    'popularity': 89,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b842388e0a8bb4c8667f77d645b25fdcd50961c1?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:4ZtFanR9U6ndgddUvNcjcG'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2xe8IXgCTpwHE3eA9hTs4n'},
#       'href': 'https://api.spotify.com/v1/artists/2xe8IXgCTpwHE3eA9hTs4n',
#       'id': '2xe8IXgCTpwHE3eA9hTs4n',
#       'name': 'BANKS',
#       'type': 'artist',
#       'uri': 'spotify:artist:2xe8IXgCTpwHE3eA9hTs4n'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0K88Nzh4Zd6ywceshg1A3B'},
#     'href': 'https://api.spotify.com/v1/albums/0K88Nzh4Zd6ywceshg1A3B',
#     'id': '0K88Nzh4Zd6ywceshg1A3B',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f3a3655a30454f65e259814c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f3a3655a30454f65e259814c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f3a3655a30454f65e259814c',
#       'width': 64}],
#     'name': 'Goddess (Remixes)',
#     'release_date': '2015-03-23',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:0K88Nzh4Zd6ywceshg1A3B'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2xe8IXgCTpwHE3eA9hTs4n'},
#      'href': 'https://api.spotify.com/v1/artists/2xe8IXgCTpwHE3eA9hTs4n',
#      'id': '2xe8IXgCTpwHE3eA9hTs4n',
#      'name': 'BANKS',
#      'type': 'artist',
#      'uri': 'spotify:artist:2xe8IXgCTpwHE3eA9hTs4n'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Gn0urVHbuAuUcv5SP6bKn'},
#      'href': 'https://api.spotify.com/v1/artists/7Gn0urVHbuAuUcv5SP6bKn',
#      'id': '7Gn0urVHbuAuUcv5SP6bKn',
#      'name': 'Andrew Swanson',
#      'type': 'artist',
#      'uri': 'spotify:artist:7Gn0urVHbuAuUcv5SP6bKn'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/24GBmL4OVczm31u0MmDLDf'},
#      'href': 'https://api.spotify.com/v1/artists/24GBmL4OVczm31u0MmDLDf',
#      'id': '24GBmL4OVczm31u0MmDLDf',
#      'name': 'Henry Allen',
#      'type': 'artist',
#      'uri': 'spotify:artist:24GBmL4OVczm31u0MmDLDf'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 252504,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71500177'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4ckVs2KqZix1xuM3ZQtNb2'},
#    'href': 'https://api.spotify.com/v1/tracks/4ckVs2KqZix1xuM3ZQtNb2',
#    'id': '4ckVs2KqZix1xuM3ZQtNb2',
#    'is_local': False,
#    'name': 'Beggin For Thread - BTS Remix',
#    'popularity': 29,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6209eb33a2c578ba073ca0e09c1603c460fe2f81?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:4ckVs2KqZix1xuM3ZQtNb2'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#       'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#       'id': '6M2wZ9GZgrQXHCFfjv46we',
#       'name': 'Dua Lipa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0ix3XtPV1LwmZADsprKxcp'},
#     'href': 'https://api.spotify.com/v1/albums/0ix3XtPV1LwmZADsprKxcp',
#     'id': '0ix3XtPV1LwmZADsprKxcp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738583df1a14bea9175f9ac520',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028583df1a14bea9175f9ac520',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518583df1a14bea9175f9ac520',
#       'width': 64}],
#     'name': "Don't Start Now",
#     'release_date': '2019-10-31',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0ix3XtPV1LwmZADsprKxcp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#      'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#      'id': '6M2wZ9GZgrQXHCFfjv46we',
#      'name': 'Dua Lipa',
#      'type': 'artist',
#      'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 183290,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAHT1901121'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6WrI0LAC5M1Rw2MnX2ZvEg'},
#    'href': 'https://api.spotify.com/v1/tracks/6WrI0LAC5M1Rw2MnX2ZvEg',
#    'id': '6WrI0LAC5M1Rw2MnX2ZvEg',
#    'is_local': False,
#    'name': "Don't Start Now",
#    'popularity': 80,
#    'preview_url': 'https://p.scdn.co/mp3-preview/87258da8a9eb8d0a0d53071e06612955e6d3b28f?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6WrI0LAC5M1Rw2MnX2ZvEg'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TIYQ3jFPwQSRmorSezPxX'},
#       'href': 'https://api.spotify.com/v1/artists/6TIYQ3jFPwQSRmorSezPxX',
#       'id': '6TIYQ3jFPwQSRmorSezPxX',
#       'name': 'Machine Gun Kelly',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TIYQ3jFPwQSRmorSezPxX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3sKZHtQoq3tPtkXbT8PJAc'},
#     'href': 'https://api.spotify.com/v1/albums/3sKZHtQoq3tPtkXbT8PJAc',
#     'id': '3sKZHtQoq3tPtkXbT8PJAc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b4683d9ac3c5f14a71523c84',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b4683d9ac3c5f14a71523c84',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b4683d9ac3c5f14a71523c84',
#       'width': 64}],
#     'name': 'mainstream sellout',
#     'release_date': '2022-03-25',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:3sKZHtQoq3tPtkXbT8PJAc'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TIYQ3jFPwQSRmorSezPxX'},
#      'href': 'https://api.spotify.com/v1/artists/6TIYQ3jFPwQSRmorSezPxX',
#      'id': '6TIYQ3jFPwQSRmorSezPxX',
#      'name': 'Machine Gun Kelly',
#      'type': 'artist',
#      'uri': 'spotify:artist:6TIYQ3jFPwQSRmorSezPxX'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3rWZHrfrsPBxVy692yAIxF'},
#      'href': 'https://api.spotify.com/v1/artists/3rWZHrfrsPBxVy692yAIxF',
#      'id': '3rWZHrfrsPBxVy692yAIxF',
#      'name': 'WILLOW',
#      'type': 'artist',
#      'uri': 'spotify:artist:3rWZHrfrsPBxVy692yAIxF'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 159096,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72112365'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3tBZ60j1jQ7NJm8IjelyQe'},
#    'href': 'https://api.spotify.com/v1/tracks/3tBZ60j1jQ7NJm8IjelyQe',
#    'id': '3tBZ60j1jQ7NJm8IjelyQe',
#    'is_local': False,
#    'name': 'emo girl (feat. WILLOW)',
#    'popularity': 70,
#    'preview_url': 'https://p.scdn.co/mp3-preview/982e70a62469af10f21025f00b7372a9ae3ff301?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:3tBZ60j1jQ7NJm8IjelyQe'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00dwwnz3V4kRfu3UFYpJLz'},
#       'href': 'https://api.spotify.com/v1/artists/00dwwnz3V4kRfu3UFYpJLz',
#       'id': '00dwwnz3V4kRfu3UFYpJLz',
#       'name': 'Cherub',
#       'type': 'artist',
#       'uri': 'spotify:artist:00dwwnz3V4kRfu3UFYpJLz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/070DVvXuLD3fM3KYs47tas'},
#     'href': 'https://api.spotify.com/v1/albums/070DVvXuLD3fM3KYs47tas',
#     'id': '070DVvXuLD3fM3KYs47tas',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738544567bdc5afbafaffc3449',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028544567bdc5afbafaffc3449',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518544567bdc5afbafaffc3449',
#       'width': 64}],
#     'name': 'Year of the Caprese',
#     'release_date': '2014',
#     'release_date_precision': 'year',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:070DVvXuLD3fM3KYs47tas'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00dwwnz3V4kRfu3UFYpJLz'},
#      'href': 'https://api.spotify.com/v1/artists/00dwwnz3V4kRfu3UFYpJLz',
#      'id': '00dwwnz3V4kRfu3UFYpJLz',
#      'name': 'Cherub',
#      'type': 'artist',
#      'uri': 'spotify:artist:00dwwnz3V4kRfu3UFYpJLz'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 323253,
#    'explicit': True,
#    'external_ids': {'isrc': 'USSM11306037'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/44CZRkOxv7UItaAUmh8PgN'},
#    'href': 'https://api.spotify.com/v1/tracks/44CZRkOxv7UItaAUmh8PgN',
#    'id': '44CZRkOxv7UItaAUmh8PgN',
#    'is_local': False,
#    'name': 'Doses & Mimosas',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/277f132ddb414e324cc6a65c463a6069e3b51150?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:44CZRkOxv7UItaAUmh8PgN'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4hDok0OAJd57SGIT8xuWJH'},
#     'href': 'https://api.spotify.com/v1/albums/4hDok0OAJd57SGIT8xuWJH',
#     'id': '4hDok0OAJd57SGIT8xuWJH',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a48964b5d9a3d6968ae3e0de',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a48964b5d9a3d6968ae3e0de',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a48964b5d9a3d6968ae3e0de',
#       'width': 64}],
#     'name': "Fearless (Taylor's Version)",
#     'release_date': '2021-04-09',
#     'release_date_precision': 'day',
#     'total_tracks': 26,
#     'type': 'album',
#     'uri': 'spotify:album:4hDok0OAJd57SGIT8xuWJH'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 200575,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12100624'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0k0vFacOHNuArLWMiH60p7'},
#    'href': 'https://api.spotify.com/v1/tracks/0k0vFacOHNuArLWMiH60p7',
#    'id': '0k0vFacOHNuArLWMiH60p7',
#    'is_local': False,
#    'name': 'Tell Me Why (Taylor’s Version)',
#    'popularity': 70,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3eb85c88a3b180093a70a32ccb75a4d6295c4e70?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:0k0vFacOHNuArLWMiH60p7'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6oX4tx055oEFYM3ahDTyOD'},
#       'href': 'https://api.spotify.com/v1/artists/6oX4tx055oEFYM3ahDTyOD',
#       'id': '6oX4tx055oEFYM3ahDTyOD',
#       'name': 'Noisettes',
#       'type': 'artist',
#       'uri': 'spotify:artist:6oX4tx055oEFYM3ahDTyOD'}],
#     'available_markets': ['CA', 'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/76VMZFtW2t9hHXdtqgwQEq'},
#     'href': 'https://api.spotify.com/v1/albums/76VMZFtW2t9hHXdtqgwQEq',
#     'id': '76VMZFtW2t9hHXdtqgwQEq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273854c8b88872561b7d61521d7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02854c8b88872561b7d61521d7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851854c8b88872561b7d61521d7',
#       'width': 64}],
#     'name': 'Wild Young Hearts',
#     'release_date': '2009-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:76VMZFtW2t9hHXdtqgwQEq'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6oX4tx055oEFYM3ahDTyOD'},
#      'href': 'https://api.spotify.com/v1/artists/6oX4tx055oEFYM3ahDTyOD',
#      'id': '6oX4tx055oEFYM3ahDTyOD',
#      'name': 'Noisettes',
#      'type': 'artist',
#      'uri': 'spotify:artist:6oX4tx055oEFYM3ahDTyOD'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 191453,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM70907200'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6roSI9jonCiMhPeLZuEn4O'},
#    'href': 'https://api.spotify.com/v1/tracks/6roSI9jonCiMhPeLZuEn4O',
#    'id': '6roSI9jonCiMhPeLZuEn4O',
#    'is_local': False,
#    'name': 'Never Forget You - US Album Version',
#    'popularity': 40,
#    'preview_url': 'https://p.scdn.co/mp3-preview/fc430848ff78521152ffafe41722ab3ac53aeef4?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:6roSI9jonCiMhPeLZuEn4O'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4hDok0OAJd57SGIT8xuWJH'},
#     'href': 'https://api.spotify.com/v1/albums/4hDok0OAJd57SGIT8xuWJH',
#     'id': '4hDok0OAJd57SGIT8xuWJH',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a48964b5d9a3d6968ae3e0de',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a48964b5d9a3d6968ae3e0de',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a48964b5d9a3d6968ae3e0de',
#       'width': 64}],
#     'name': "Fearless (Taylor's Version)",
#     'release_date': '2021-04-09',
#     'release_date_precision': 'day',
#     'total_tracks': 26,
#     'type': 'album',
#     'uri': 'spotify:album:4hDok0OAJd57SGIT8xuWJH'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 238443,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12100635'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1cSFlSBdpT4F5vb1frQ231'},
#    'href': 'https://api.spotify.com/v1/tracks/1cSFlSBdpT4F5vb1frQ231',
#    'id': '1cSFlSBdpT4F5vb1frQ231',
#    'is_local': False,
#    'name': 'The Other Side Of The Door (Taylor’s Version)',
#    'popularity': 73,
#    'preview_url': 'https://p.scdn.co/mp3-preview/98b765b6cef81de5a4a97e8df71b9453e21e5845?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 19,
#    'type': 'track',
#    'uri': 'spotify:track:1cSFlSBdpT4F5vb1frQ231'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#       'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#       'id': '1McMsnEElThX1knmY4oliG',
#       'name': 'Olivia Rodrigo',
#       'type': 'artist',
#       'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6s84u2TUpR3wdUv4NgKA2j'},
#     'href': 'https://api.spotify.com/v1/albums/6s84u2TUpR3wdUv4NgKA2j',
#     'id': '6s84u2TUpR3wdUv4NgKA2j',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a91c10fe9472d9bd89802e5a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a91c10fe9472d9bd89802e5a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a91c10fe9472d9bd89802e5a',
#       'width': 64}],
#     'name': 'SOUR',
#     'release_date': '2021-05-21',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6s84u2TUpR3wdUv4NgKA2j'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#      'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#      'id': '1McMsnEElThX1knmY4oliG',
#      'name': 'Olivia Rodrigo',
#      'type': 'artist',
#      'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 143746,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG12101242'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6SRsiMl7w1USE4mFqrOhHC'},
#    'href': 'https://api.spotify.com/v1/tracks/6SRsiMl7w1USE4mFqrOhHC',
#    'id': '6SRsiMl7w1USE4mFqrOhHC',
#    'is_local': False,
#    'name': 'brutal',
#    'popularity': 82,
#    'preview_url': 'https://p.scdn.co/mp3-preview/30a4c1f7cd1a45e2de45627deb66a685edd10e1b?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6SRsiMl7w1USE4mFqrOhHC'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#       'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#       'id': '1McMsnEElThX1knmY4oliG',
#       'name': 'Olivia Rodrigo',
#       'type': 'artist',
#       'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/66FPnVL9G4CMKy3wvaGTcr'},
#     'href': 'https://api.spotify.com/v1/albums/66FPnVL9G4CMKy3wvaGTcr',
#     'id': '66FPnVL9G4CMKy3wvaGTcr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738ffc294c1c4362e8472d14cd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028ffc294c1c4362e8472d14cd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518ffc294c1c4362e8472d14cd',
#       'width': 64}],
#     'name': 'drivers license',
#     'release_date': '2021-01-08',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:66FPnVL9G4CMKy3wvaGTcr'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#      'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#      'id': '1McMsnEElThX1knmY4oliG',
#      'name': 'Olivia Rodrigo',
#      'type': 'artist',
#      'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 242013,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG12004749'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7lPN2DXiMsVn7XUKtOW1CS'},
#    'href': 'https://api.spotify.com/v1/tracks/7lPN2DXiMsVn7XUKtOW1CS',
#    'id': '7lPN2DXiMsVn7XUKtOW1CS',
#    'is_local': False,
#    'name': 'drivers license',
#    'popularity': 30,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7lPN2DXiMsVn7XUKtOW1CS'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TIYQ3jFPwQSRmorSezPxX'},
#       'href': 'https://api.spotify.com/v1/artists/6TIYQ3jFPwQSRmorSezPxX',
#       'id': '6TIYQ3jFPwQSRmorSezPxX',
#       'name': 'Machine Gun Kelly',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TIYQ3jFPwQSRmorSezPxX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
# ...
#    'href': 'https://api.spotify.com/v1/tracks/37ZKB38iNyKJ0xYEz9SJgk',
#    'id': '37ZKB38iNyKJ0xYEz9SJgk',
#    'is_local': False,
#    'name': 'Josslyn',
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a119ce01e862332ed772d7a7d9d34d5de15ee364?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:37ZKB38iNyKJ0xYEz9SJgk'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TIYQ3jFPwQSRmorSezPxX'},
#       'href': 'https://api.spotify.com/v1/artists/6TIYQ3jFPwQSRmorSezPxX',
#       'id': '6TIYQ3jFPwQSRmorSezPxX',
#       'name': 'Machine Gun Kelly',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TIYQ3jFPwQSRmorSezPxX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3sKZHtQoq3tPtkXbT8PJAc'},
#     'href': 'https://api.spotify.com/v1/albums/3sKZHtQoq3tPtkXbT8PJAc',
#     'id': '3sKZHtQoq3tPtkXbT8PJAc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b4683d9ac3c5f14a71523c84',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b4683d9ac3c5f14a71523c84',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b4683d9ac3c5f14a71523c84',
#       'width': 64}],
#     'name': 'mainstream sellout',
#     'release_date': '2022-03-25',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:3sKZHtQoq3tPtkXbT8PJAc'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TIYQ3jFPwQSRmorSezPxX'},
#      'href': 'https://api.spotify.com/v1/artists/6TIYQ3jFPwQSRmorSezPxX',
#      'id': '6TIYQ3jFPwQSRmorSezPxX',
#      'name': 'Machine Gun Kelly',
#      'type': 'artist',
#      'uri': 'spotify:artist:6TIYQ3jFPwQSRmorSezPxX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 239212,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72112357'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4pR5ZEROnKQpJttWNn5er6'},
#    'href': 'https://api.spotify.com/v1/tracks/4pR5ZEROnKQpJttWNn5er6',
#    'id': '4pR5ZEROnKQpJttWNn5er6',
#    'is_local': False,
#    'name': 'twin flame',
#    'popularity': 66,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e44d6f9a9a186f6de94e661c68bf40f906c8c65b?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:4pR5ZEROnKQpJttWNn5er6'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6DEjYFkNZh67HP7R9PSZvv'},
#     'href': 'https://api.spotify.com/v1/albums/6DEjYFkNZh67HP7R9PSZvv',
#     'id': '6DEjYFkNZh67HP7R9PSZvv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273da5d5aeeabacacc1263c0f4b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02da5d5aeeabacacc1263c0f4b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851da5d5aeeabacacc1263c0f4b',
#       'width': 64}],
#     'name': 'reputation',
#     'release_date': '2017-11-10',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:6DEjYFkNZh67HP7R9PSZvv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 238253,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCJY1750005'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4svZDCRz4cJoneBpjpx8DJ'},
#    'href': 'https://api.spotify.com/v1/tracks/4svZDCRz4cJoneBpjpx8DJ',
#    'id': '4svZDCRz4cJoneBpjpx8DJ',
#    'is_local': False,
#    'name': 'I Did Something Bad',
#    'popularity': 83,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ef43901885fc52988f3192152a8019fc7a34f0d5?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:4svZDCRz4cJoneBpjpx8DJ'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hAd6zwEgt9ILuMDY1prcI'},
#       'href': 'https://api.spotify.com/v1/artists/0hAd6zwEgt9ILuMDY1prcI',
#       'id': '0hAd6zwEgt9ILuMDY1prcI',
#       'name': 'Palaye Royale',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hAd6zwEgt9ILuMDY1prcI'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6R8AAzKYJ7KrmYx0DYosy3'},
#     'href': 'https://api.spotify.com/v1/albums/6R8AAzKYJ7KrmYx0DYosy3',
#     'id': '6R8AAzKYJ7KrmYx0DYosy3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738b4ccd9ded99f375eeeee594',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028b4ccd9ded99f375eeeee594',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518b4ccd9ded99f375eeeee594',
#       'width': 64}],
#     'name': 'Boom Boom Room (Side B)',
#     'release_date': '2018-09-28',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:6R8AAzKYJ7KrmYx0DYosy3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hAd6zwEgt9ILuMDY1prcI'},
#      'href': 'https://api.spotify.com/v1/artists/0hAd6zwEgt9ILuMDY1prcI',
#      'id': '0hAd6zwEgt9ILuMDY1prcI',
#      'name': 'Palaye Royale',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hAd6zwEgt9ILuMDY1prcI'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 228626,
#    'explicit': False,
#    'external_ids': {'isrc': 'USYFZ1812304'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0kwbhAzmXoEfv1XAccsLGh'},
#    'href': 'https://api.spotify.com/v1/tracks/0kwbhAzmXoEfv1XAccsLGh',
#    'id': '0kwbhAzmXoEfv1XAccsLGh',
#    'is_local': False,
#    'name': 'Dying In A Hot Tub',
#    'popularity': 1,
#    'preview_url': None,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:0kwbhAzmXoEfv1XAccsLGh'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#       'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#       'id': '1McMsnEElThX1knmY4oliG',
#       'name': 'Olivia Rodrigo',
#       'type': 'artist',
#       'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3rMjL8NA5Wh2hbMNk2fSlY'},
#     'href': 'https://api.spotify.com/v1/albums/3rMjL8NA5Wh2hbMNk2fSlY',
#     'id': '3rMjL8NA5Wh2hbMNk2fSlY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273670ec029374e082f921f9f74',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02670ec029374e082f921f9f74',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851670ec029374e082f921f9f74',
#       'width': 64}],
#     'name': 'good 4 u',
#     'release_date': '2021-05-14',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3rMjL8NA5Wh2hbMNk2fSlY'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#      'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#      'id': '1McMsnEElThX1knmY4oliG',
#      'name': 'Olivia Rodrigo',
#      'type': 'artist',
#      'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 178147,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG12101245'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6PERP62TejQjgHu81OHxgM'},
#    'href': 'https://api.spotify.com/v1/tracks/6PERP62TejQjgHu81OHxgM',
#    'id': '6PERP62TejQjgHu81OHxgM',
#    'is_local': False,
#    'name': 'good 4 u',
#    'popularity': 26,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6PERP62TejQjgHu81OHxgM'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7o2ZQYM7nTsaVdkXY38UAA'},
#       'href': 'https://api.spotify.com/v1/artists/7o2ZQYM7nTsaVdkXY38UAA',
#       'id': '7o2ZQYM7nTsaVdkXY38UAA',
#       'name': 'Em Beihold',
#       'type': 'artist',
#       'uri': 'spotify:artist:7o2ZQYM7nTsaVdkXY38UAA'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/20zaiRxxUfDqdCKsdSo7HM'},
#     'href': 'https://api.spotify.com/v1/albums/20zaiRxxUfDqdCKsdSo7HM',
#     'id': '20zaiRxxUfDqdCKsdSo7HM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dc0353a5801934f9a4bac01d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dc0353a5801934f9a4bac01d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dc0353a5801934f9a4bac01d',
#       'width': 64}],
#     'name': 'Numb Little Bug',
#     'release_date': '2022-01-28',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:20zaiRxxUfDqdCKsdSo7HM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7o2ZQYM7nTsaVdkXY38UAA'},
#      'href': 'https://api.spotify.com/v1/artists/7o2ZQYM7nTsaVdkXY38UAA',
#      'id': '7o2ZQYM7nTsaVdkXY38UAA',
#      'name': 'Em Beihold',
#      'type': 'artist',
#      'uri': 'spotify:artist:7o2ZQYM7nTsaVdkXY38UAA'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 169237,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72200626'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3o9kpgkIcffx0iSwxhuNI2'},
#    'href': 'https://api.spotify.com/v1/tracks/3o9kpgkIcffx0iSwxhuNI2',
#    'id': '3o9kpgkIcffx0iSwxhuNI2',
#    'is_local': False,
#    'name': 'Numb Little Bug',
#    'popularity': 78,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b9233d42f5ed9aa12756ea783f03eead8f9f1a3a?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3o9kpgkIcffx0iSwxhuNI2'}],
#  'total': 50,
#  'limit': 50,
#  'offset': 0,
#  'href': 'https://api.spotify.com/v1/me/top/tracks?limit=50&offset=0&time_range=long_term',
#  'next': None,
#  'previous': None}

# %%
top_tracks["items"][0]['album']['album_type']
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#  'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#  'id': '1McMsnEElThX1knmY4oliG',
#  'name': 'Olivia Rodrigo',
#  'type': 'artist',
#  'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}

# %%
output_dict = [x for x in top_tracks["items"] if x['artists'][0]['name'] == 'Taylor Swift' and x['album']['album_type'] == 'ALBUM']

# %%
output_dict
# Out:
# [{'album': {'album_type': 'ALBUM',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6DEjYFkNZh67HP7R9PSZvv'},
#    'href': 'https://api.spotify.com/v1/albums/6DEjYFkNZh67HP7R9PSZvv',
#    'id': '6DEjYFkNZh67HP7R9PSZvv',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273da5d5aeeabacacc1263c0f4b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02da5d5aeeabacacc1263c0f4b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851da5d5aeeabacacc1263c0f4b',
#      'width': 64}],
#    'name': 'reputation',
#    'release_date': '2017-11-10',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:6DEjYFkNZh67HP7R9PSZvv'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 233626,
#   'explicit': False,
#   'external_ids': {'isrc': 'USCJY1750010'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0VE4kBnHJUgtMf0dy6DRmW'},
#   'href': 'https://api.spotify.com/v1/tracks/0VE4kBnHJUgtMf0dy6DRmW',
#   'id': '0VE4kBnHJUgtMf0dy6DRmW',
#   'is_local': False,
#   'name': 'Getaway Car',
#   'popularity': 88,
#   'preview_url': 'https://p.scdn.co/mp3-preview/3b7c75273822da52311019692f2db7b933d1b74f?cid=44241990678a457fac9fd0654a4f6a30',
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:0VE4kBnHJUgtMf0dy6DRmW'},
#  {'album': {'album_type': 'ALBUM',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#    'href': 'https://api.spotify.com/v1/albums/1NAmidJlEaVgA3MpcPFYGq',
#    'id': '1NAmidJlEaVgA3MpcPFYGq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e787cffec20aa2a396a61647',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e787cffec20aa2a396a61647',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e787cffec20aa2a396a61647',
#      'width': 64}],
#    'name': 'Lover',
#    'release_date': '2019-08-23',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:1NAmidJlEaVgA3MpcPFYGq'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 178426,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG11901472'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1BxfuPKGuaTgP7aM0Bbdwr'},
#   'href': 'https://api.spotify.com/v1/tracks/1BxfuPKGuaTgP7aM0Bbdwr',
#   'id': '1BxfuPKGuaTgP7aM0Bbdwr',
#   'is_local': False,
#   'name': 'Cruel Summer',
#   'popularity': 98,
#   'preview_url': 'https://p.scdn.co/mp3-preview/dba15da5409f3c808022cf927c0ff8581f717aa4?cid=44241990678a457fac9fd0654a4f6a30',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:1BxfuPKGuaTgP7aM0Bbdwr'},
#  {'album': {'album_type': 'ALBUM',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4hDok0OAJd57SGIT8xuWJH'},
#    'href': 'https://api.spotify.com/v1/albums/4hDok0OAJd57SGIT8xuWJH',
#    'id': '4hDok0OAJd57SGIT8xuWJH',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a48964b5d9a3d6968ae3e0de',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a48964b5d9a3d6968ae3e0de',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a48964b5d9a3d6968ae3e0de',
#      'width': 64}],
#    'name': "Fearless (Taylor's Version)",
#    'release_date': '2021-04-09',
#    'release_date_precision': 'day',
#    'total_tracks': 26,
#    'type': 'album',
#    'uri': 'spotify:album:4hDok0OAJd57SGIT8xuWJH'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 200575,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG12100624'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0k0vFacOHNuArLWMiH60p7'},
#   'href': 'https://api.spotify.com/v1/tracks/0k0vFacOHNuArLWMiH60p7',
#   'id': '0k0vFacOHNuArLWMiH60p7',
#   'is_local': False,
#   'name': 'Tell Me Why (Taylor’s Version)',
#   'popularity': 70,
#   'preview_url': 'https://p.scdn.co/mp3-preview/3eb85c88a3b180093a70a32ccb75a4d6295c4e70?cid=44241990678a457fac9fd0654a4f6a30',
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:0k0vFacOHNuArLWMiH60p7'},
#  {'album': {'album_type': 'ALBUM',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4hDok0OAJd57SGIT8xuWJH'},
#    'href': 'https://api.spotify.com/v1/albums/4hDok0OAJd57SGIT8xuWJH',
#    'id': '4hDok0OAJd57SGIT8xuWJH',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a48964b5d9a3d6968ae3e0de',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a48964b5d9a3d6968ae3e0de',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a48964b5d9a3d6968ae3e0de',
#      'width': 64}],
#    'name': "Fearless (Taylor's Version)",
#    'release_date': '2021-04-09',
#    'release_date_precision': 'day',
#    'total_tracks': 26,
#    'type': 'album',
#    'uri': 'spotify:album:4hDok0OAJd57SGIT8xuWJH'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 238443,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG12100635'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1cSFlSBdpT4F5vb1frQ231'},
#   'href': 'https://api.spotify.com/v1/tracks/1cSFlSBdpT4F5vb1frQ231',
#   'id': '1cSFlSBdpT4F5vb1frQ231',
#   'is_local': False,
#   'name': 'The Other Side Of The Door (Taylor’s Version)',
#   'popularity': 73,
#   'preview_url': 'https://p.scdn.co/mp3-preview/98b765b6cef81de5a4a97e8df71b9453e21e5845?cid=44241990678a457fac9fd0654a4f6a30',
#   'track_number': 19,
#   'type': 'track',
#   'uri': 'spotify:track:1cSFlSBdpT4F5vb1frQ231'},
#  {'album': {'album_type': 'ALBUM',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6kZ42qRrzov54LcAk4onW9'},
#    'href': 'https://api.spotify.com/v1/albums/6kZ42qRrzov54LcAk4onW9',
#    'id': '6kZ42qRrzov54LcAk4onW9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273318443aab3531a0558e79a4d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02318443aab3531a0558e79a4d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851318443aab3531a0558e79a4d',
#      'width': 64}],
#    'name': "Red (Taylor's Version)",
#    'release_date': '2021-11-12',
#    'release_date_precision': 'day',
#    'total_tracks': 30,
#    'type': 'album',
#    'uri': 'spotify:album:6kZ42qRrzov54LcAk4onW9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 613026,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG12103690'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5enxwA8aAbwZbf5qCHORXi'},
#   'href': 'https://api.spotify.com/v1/tracks/5enxwA8aAbwZbf5qCHORXi',
#   'id': '5enxwA8aAbwZbf5qCHORXi',
#   'is_local': False,
#   'name': "All Too Well (10 Minute Version) (Taylor's Version) (From The Vault)",
#   'popularity': 88,
#   'preview_url': 'https://p.scdn.co/mp3-preview/57b5f697db04a6f463de366927093882cfd5a00b?cid=44241990678a457fac9fd0654a4f6a30',
#   'track_number': 30,
#   'type': 'track',
#   'uri': 'spotify:track:5enxwA8aAbwZbf5qCHORXi'},
#  {'album': {'album_type': 'ALBUM',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2QJmrSgbdM35R67eoGQo4j'},
#    'href': 'https://api.spotify.com/v1/albums/2QJmrSgbdM35R67eoGQo4j',
#    'id': '2QJmrSgbdM35R67eoGQo4j',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2739abdf14e6058bd3903686148',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e029abdf14e6058bd3903686148',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048519abdf14e6058bd3903686148',
#      'width': 64}],
#    'name': '1989',
#    'release_date': '2014-10-27',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:2QJmrSgbdM35R67eoGQo4j'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 235800,
#   'explicit': False,
#   'external_ids': {'isrc': 'USCJY1431329'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5OndtwLGA9O6XHFcGm2H7r'},
#   'href': 'https://api.spotify.com/v1/tracks/5OndtwLGA9O6XHFcGm2H7r',
#   'id': '5OndtwLGA9O6XHFcGm2H7r',
#   'is_local': False,
#   'name': 'Out Of The Woods',
#   'popularity': 73,
#   'preview_url': 'https://p.scdn.co/mp3-preview/d130f44a286097bf753d8df40ff24b53cfc0e5a2?cid=44241990678a457fac9fd0654a4f6a30',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:5OndtwLGA9O6XHFcGm2H7r'},
#  {'album': {'album_type': 'ALBUM',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4hDok0OAJd57SGIT8xuWJH'},
#    'href': 'https://api.spotify.com/v1/albums/4hDok0OAJd57SGIT8xuWJH',
#    'id': '4hDok0OAJd57SGIT8xuWJH',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a48964b5d9a3d6968ae3e0de',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a48964b5d9a3d6968ae3e0de',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a48964b5d9a3d6968ae3e0de',
#      'width': 64}],
#    'name': "Fearless (Taylor's Version)",
#    'release_date': '2021-04-09',
#    'release_date_precision': 'day',
#    'total_tracks': 26,
#    'type': 'album',
#    'uri': 'spotify:album:4hDok0OAJd57SGIT8xuWJH'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 243136,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG12100626'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/22bPsP2jCgbLUvh82U0Z3M'},
#   'href': 'https://api.spotify.com/v1/tracks/22bPsP2jCgbLUvh82U0Z3M',
#   'id': '22bPsP2jCgbLUvh82U0Z3M',
#   'is_local': False,
#   'name': 'The Way I Loved You (Taylor’s Version)',
#   'popularity': 86,
#   'preview_url': 'https://p.scdn.co/mp3-preview/d40ac5b2f3d937665df2deb68f81d73fa982cd01?cid=44241990678a457fac9fd0654a4f6a30',
#   'track_number': 10,
#   'type': 'track',
#   'uri': 'spotify:track:22bPsP2jCgbLUvh82U0Z3M'},
#  {'album': {'album_type': 'ALBUM',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6DEjYFkNZh67HP7R9PSZvv'},
#    'href': 'https://api.spotify.com/v1/albums/6DEjYFkNZh67HP7R9PSZvv',
#    'id': '6DEjYFkNZh67HP7R9PSZvv',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273da5d5aeeabacacc1263c0f4b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02da5d5aeeabacacc1263c0f4b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851da5d5aeeabacacc1263c0f4b',
#      'width': 64}],
#    'name': 'reputation',
#    'release_date': '2017-11-10',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:6DEjYFkNZh67HP7R9PSZvv'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 236413,
#   'explicit': False,
#   'external_ids': {'isrc': 'USCJY1750006'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1R0a2iXumgCiFb7HEZ7gUE'},
#   'href': 'https://api.spotify.com/v1/tracks/1R0a2iXumgCiFb7HEZ7gUE',
#   'id': '1R0a2iXumgCiFb7HEZ7gUE',
#   'is_local': False,
#   'name': 'Don’t Blame Me',
#   'popularity': 92,
#   'preview_url': 'https://p.scdn.co/mp3-preview/8edf06fbc7550b9c8801cc30980e1230af5d6aae?cid=44241990678a457fac9fd0654a4f6a30',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:1R0a2iXumgCiFb7HEZ7gUE'},
#  {'album': {'album_type': 'ALBUM',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4hDok0OAJd57SGIT8xuWJH'},
#    'href': 'https://api.spotify.com/v1/albums/4hDok0OAJd57SGIT8xuWJH',
#    'id': '4hDok0OAJd57SGIT8xuWJH',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a48964b5d9a3d6968ae3e0de',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a48964b5d9a3d6968ae3e0de',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a48964b5d9a3d6968ae3e0de',
#      'width': 64}],
#    'name': "Fearless (Taylor's Version)",
#    'release_date': '2021-04-09',
#    'release_date_precision': 'day',
#    'total_tracks': 26,
#    'type': 'album',
#    'uri': 'spotify:album:4hDok0OAJd57SGIT8xuWJH'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 277591,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG12100638'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2CYVETnhM9aytqrazYYwrK'},
#   'href': 'https://api.spotify.com/v1/tracks/2CYVETnhM9aytqrazYYwrK',
#   'id': '2CYVETnhM9aytqrazYYwrK',
#   'is_local': False,
#   'name': 'Mr. Perfectly Fine (Taylor’s Version) (From The Vault)',
#   'popularity': 79,
#   'preview_url': 'https://p.scdn.co/mp3-preview/4d0ccbc49a2804544b958324ebfd51e6a1b97b0d?cid=44241990678a457fac9fd0654a4f6a30',
#   'track_number': 22,
#   'type': 'track',
#   'uri': 'spotify:track:2CYVETnhM9aytqrazYYwrK'},
#  {'album': {'album_type': 'ALBUM',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6DEjYFkNZh67HP7R9PSZvv'},
#    'href': 'https://api.spotify.com/v1/albums/6DEjYFkNZh67HP7R9PSZvv',
#    'id': '6DEjYFkNZh67HP7R9PSZvv',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273da5d5aeeabacacc1263c0f4b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02da5d5aeeabacacc1263c0f4b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851da5d5aeeabacacc1263c0f4b',
#      'width': 64}],
#    'name': 'reputation',
#    'release_date': '2017-11-10',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:6DEjYFkNZh67HP7R9PSZvv'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 238253,
#   'explicit': False,
#   'external_ids': {'isrc': 'USCJY1750005'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4svZDCRz4cJoneBpjpx8DJ'},
#   'href': 'https://api.spotify.com/v1/tracks/4svZDCRz4cJoneBpjpx8DJ',
#   'id': '4svZDCRz4cJoneBpjpx8DJ',
#   'is_local': False,
#   'name': 'I Did Something Bad',
#   'popularity': 83,
#   'preview_url': 'https://p.scdn.co/mp3-preview/ef43901885fc52988f3192152a8019fc7a34f0d5?cid=44241990678a457fac9fd0654a4f6a30',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:4svZDCRz4cJoneBpjpx8DJ'}]

# %%
result = output_dict[0]["album"]['name']

result
# Out:
# 'reputation'

# %%
spotify:track:spotify:track:00vJzaoxM3Eja1doBUhX0P

# %%
track_test = sp.track('4RBKAqJ3qyvvriDG0s9IJ3')

# %%
track_test
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1ycoesYxIFymXWebfmz828'},
#   'href': 'https://api.spotify.com/v1/albums/1ycoesYxIFymXWebfmz828',
#   'id': '1ycoesYxIFymXWebfmz828',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c031e8322b3e8684536ed6d0',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c031e8322b3e8684536ed6d0',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c031e8322b3e8684536ed6d0',
#     'width': 64}],
#   'name': 'Live From Clear Channel Stripped 2008',
#   'release_date': '2008-06-28',
#   'release_date_precision': 'day',
#   'total_tracks': 8,
#   'type': 'album',
#   'uri': 'spotify:album:1ycoesYxIFymXWebfmz828'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#    'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#    'id': '06HL4z0CvFAxyc27GXpf02',
#    'name': 'Taylor Swift',
#    'type': 'artist',
#    'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 221028,
#  'explicit': False,
#  'external_ids': {'isrc': 'USCJY0803480'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/4RBKAqJ3qyvvriDG0s9IJ3'},
#  'href': 'https://api.spotify.com/v1/tracks/4RBKAqJ3qyvvriDG0s9IJ3',
#  'id': '4RBKAqJ3qyvvriDG0s9IJ3',
#  'is_local': False,
#  'name': 'Love Story - Live From Clear Channel Stripped 2008',
#  'popularity': 44,
#  'preview_url': 'https://p.scdn.co/mp3-preview/ad354960229f3e1610a52010e40fb7092cf3de97?cid=44241990678a457fac9fd0654a4f6a30',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:4RBKAqJ3qyvvriDG0s9IJ3'}

# %%
result = 'Midnights (3am Edition)'

# %%
# results from json extraction
if result == 'Midnights (The Til Dawn Edition)' or result == 'Midnights (3am Edition)' or result =='Midnights':
    era_name = "Midnights"
elif result == "Red (Taylor's Version)" or result == 'Red' or result == "Red (Deluxe Edition)":
    era_name = "Red"
elif result == "Fearless (Taylor's Version)" or result == 'Fearless' or result == "Fearless Platinum Edition":
    era_name = "Fearless"
elif result == "evermore (deluxe version)" or result == 'evermore':
    era_name = "evermore"
elif result == "folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]" or result == 'folklore (deluxe version)' or result == "folklore":
    era_name = "folklore"
elif result == "Lover":
    era_name = "Lover"
elif result == "reputation" or result == 'reputation Stadium Tour Surprise Song Playlist':
    era_name = "reputation"
elif result == "1989 (Taylor's Version)" or result == '1989' or result == "1989 (Deluxe Edition)":
    era_name = "1989"
elif result == "Speak Now (Taylor's Version)" or result == "Speak Now" or result == "Speak Now (Deluxe Edition)" or result == "Speak Now World Tour Live":
    era_name = "Speak Now"
elif result == "Taylor Swift" or result == 'Live From Clear Channel Stripped 2008':
    era_name = "Taylor Swift Debut"
else:
    era_name = "UH OH, you need to listen to more Taylor Swift"

# %%
# if album is single - match the name of the song

# %%
era_name
# Out:
# 'Midnights'
