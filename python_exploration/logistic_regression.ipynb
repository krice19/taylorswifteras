# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

import spotipy
import spotipy.util as util
from config import client_id, client_secret

redirect_uri = 'http://localhost:7777/callback'
scope = 'user-top-read'

token = util.prompt_for_user_token(
                                   scope=scope, 
                                   client_id=client_id,   
                                   client_secret=client_secret,     
                                   redirect_uri=redirect_uri)

classifier = LogisticRegression(solver='lbfgs', random_state=1)
label_encoder = LabelEncoder()

# %%
df = pd.read_csv("all_taylor_features.csv")

# %%
df.head()
# Out:
#    Unnamed: 0         album  danceability  energy  key  loudness  mode  \
# 0           0  Taylor SWift         0.580   0.491    0    -6.462     1
# 1           1  Taylor SWift         0.658   0.877    7    -2.098     1
# 2           2  Taylor SWift         0.621   0.417   10    -6.941     1
# 3           3  Taylor SWift         0.576   0.777    9    -2.881     1
# 4           4  Taylor SWift         0.418   0.482    5    -5.769     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 0       0.0251         0.575               0.0    0.1210    0.425   76.009
# 1       0.0323         0.173               0.0    0.0962    0.821  105.586
# 2       0.0231         0.288               0.0    0.1190    0.289   99.953
# 3       0.0324         0.051               0.0    0.3200    0.428  115.028
# 4       0.0266         0.217               0.0    0.1230    0.261  175.558

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# album                object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# dtype: object

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#              album  danceability  energy  key  loudness  mode  speechiness  \
# 0     Taylor SWift         0.580   0.491    0    -6.462     1       0.0251
# 1     Taylor SWift         0.658   0.877    7    -2.098     1       0.0323
# 2     Taylor SWift         0.621   0.417   10    -6.941     1       0.0231
# 3     Taylor SWift         0.576   0.777    9    -2.881     1       0.0324
# 4     Taylor SWift         0.418   0.482    5    -5.769     1       0.0266
# ..             ...           ...     ...  ...       ...   ...          ...
# 177  Midnights 3AM         0.700   0.509    7   -10.547     1       0.0789
# 178  Midnights 3AM         0.646   0.529   10   -10.179     1       0.0864
# 179  Midnights 3AM         0.675   0.466   11    -9.738     0       0.2010
# 180  Midnights 3AM         0.483   0.840    7    -6.508     1       0.1190
# 181  Midnights 3AM         0.562   0.388    0   -12.088     1       0.0705
#
#      acousticness  instrumentalness  liveness  valence    tempo
# 0           0.575          0.000000    0.1210    0.425   76.009
# 1           0.173          0.000000    0.0962    0.821  105.586
# 2           0.288          0.000000    0.1190    0.289   99.953
# 3           0.051          0.000000    0.3200    0.428  115.028
# 4           0.217          0.000000    0.1230    0.261  175.558
# ..            ...               ...       ...      ...      ...
# 177         0.112          0.000033    0.1370    0.345  110.947
# 178         0.723          0.000000    0.0885    0.755   87.862
# 179         0.361          0.000000    0.1100    0.347  140.864
# 180         0.430          0.000575    0.1460    0.550  157.979
# 181         0.481          0.001450    0.1170    0.159  107.747
#
# [182 rows x 12 columns]

# %%
df["album_outcome"] = label_encoder.fit_transform(df["album"])

# %%
df.dtypes
# Out:
# album                object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# album_outcome         int64
# dtype: object

# %%
df.query("album == 'Taylor SWift'")
# Out:
#            album  danceability  energy  key  loudness  mode  speechiness  \
# 0   Taylor SWift         0.580   0.491    0    -6.462     1       0.0251
# 1   Taylor SWift         0.658   0.877    7    -2.098     1       0.0323
# 2   Taylor SWift         0.621   0.417   10    -6.941     1       0.0231
# 3   Taylor SWift         0.576   0.777    9    -2.881     1       0.0324
# 4   Taylor SWift         0.418   0.482    5    -5.769     1       0.0266
# 5   Taylor SWift         0.589   0.805    5    -4.055     1       0.0293
# 6   Taylor SWift         0.479   0.578    2    -4.963     1       0.0294
# 7   Taylor SWift         0.594   0.629    8    -4.919     1       0.0246
# 8   Taylor SWift         0.476   0.777    4    -3.771     0       0.0289
# 9   Taylor SWift         0.403   0.627    2    -5.280     1       0.0292
# 10  Taylor SWift         0.668   0.672    2    -4.931     1       0.0303
# 11  Taylor SWift         0.563   0.934    8    -3.629     1       0.0646
# 12  Taylor SWift         0.612   0.394    7    -5.723     1       0.0243
# 13  Taylor SWift         0.483   0.751    4    -5.726     1       0.0365
# 14  Taylor SWift         0.459   0.753   10    -3.827     1       0.0537
#
#     acousticness  instrumentalness  liveness  valence    tempo  album_outcome
# 0        0.57500          0.000000    0.1210    0.425   76.009              9
# 1        0.17300          0.000000    0.0962    0.821  105.586              9
# 2        0.28800          0.000000    0.1190    0.289   99.953              9
# 3        0.05100          0.000000    0.3200    0.428  115.028              9
# 4        0.21700          0.000000    0.1230    0.261  175.558              9
# 5        0.00491          0.000000    0.2400    0.591  112.982              9
# 6        0.52500          0.000000    0.0841    0.192  146.165              9
# 7        0.08680          0.000000    0.1370    0.504  131.597              9
# 8        0.01030          0.000000    0.1960    0.472  167.964              9
# 9        0.01770          0.000000    0.1820    0.374   74.900              9
# 10       0.11100          0.000000    0.3290    0.539   89.011              9
# 11       0.00452          0.000807    0.1030    0.518  143.964              9
# 12       0.63700          0.000000    0.1470    0.233   96.001              9
# 13       0.00349          0.000000    0.1280    0.268  156.092              9
# 14       0.04020          0.000000    0.0863    0.483  199.997              9

# %%
df.groupby(["album", "album_outcome"]).size().reset_index()
# Out:
#                        album  album_outcome   0
# 0                       1989              0  13
# 1                   Evermore              1  15
# 2  Fearless Taylor's Version              2  26
# 3                   Folklore              3  16
# 4                      Lover              4  18
# 5              Midnights 3AM              5  20
# 6       Red Taylor's Verison              6  30
# 7                 Reputation              7  15
# 8                  Speak Now              8  14
# 9               Taylor SWift              9  15

# %%
y = df["album_outcome"]
x = df.drop(columns=["album","album_outcome"])

# %%
classifier.fit(x, y)
# Out:
# /Users/kellyrice/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression(random_state=1)

# %%
sp = spotipy.Spotify(auth=token)

# %%
top_tracks = sp.current_user_top_tracks(limit=5,time_range='short_term')

# %%
#putting the name of a song in the list
top_songs =[]
for idx, item in enumerate(top_tracks['items']):
    top_songs.append(item['id'])

# %%
#getting audio features of those top 5 songs
features = []
for id in top_songs:
    features.append(sp.audio_features(id))

# %%
#setting empty list for all the song features
dance = []
energy = []
key = []
loud = []
mode = []
speech = []
acoustic = []
instrument = []
liveness = []
valence = []
tempo = []

# %%
#count of top songs
song_count = len(top_songs)
song_count
# Out:
# 5

# %%
#adding all the features from the JSON to the list
for i in range(song_count):
    dance.append(features[i][0]["danceability"])
    energy.append(features[i][0]["energy"])
    key.append(features[i][0]["key"])
    loud.append(features[i][0]["loudness"])
    mode.append(features[i][0]["mode"])
    speech.append(features[i][0]["speechiness"])
    acoustic.append(features[i][0]["acousticness"])
    instrument.append(features[i][0]["instrumentalness"])
    liveness.append(features[i][0]["liveness"])
    valence.append(features[i][0]["valence"])
    tempo.append(features[i][0]["tempo"])

# %%
#create dictionary from list
song_dict = dict(danceability=dance, 
                 energy =energy,
                 key =key,
                 loudness=loud,
                 mode=mode,
                 speechiness=speech,
                 acousticness=acoustic,
                 instrumentalness=instrument,
                 liveness=liveness,
                 valence=valence,
                 tempo=tempo)

# %%
song_df = pd.DataFrame(song_dict)

# %%
song_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.511   0.532    5    -5.745     1       0.0560         0.169
# 1         0.537   0.537    8   -11.266     1       0.0617         0.819
# 2         0.423   0.857    2    -5.173     1       0.0687         0.188
# 3         0.456   0.263    0   -10.630     1       0.0332         0.806
# 4         0.502   0.462   11    -7.526     1       0.0265         0.578
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000000    0.3110    0.322  137.827
# 1          0.000904    0.1420    0.292  107.895
# 2          0.000026    0.1050    0.196   75.024
# 3          0.000000    0.0749    0.111  129.860
# 4          0.000000    0.7210    0.304   97.085

# %%
x_test = song_df

# %%
y_pred = classifier.predict(x_test)

# %%
y_pred
# Out:
# array([2, 5, 6, 5, 1])

# %%
top_songs_names =[]
for idx, item in enumerate(top_tracks['items']):
    top_songs_names.append(item['name'])

# %%
top_songs_names
# Out:
# ['vampire',
#  'coney island (feat. The National)',
#  'Radio',
#  'my tears ricochet',
#  'Cornelia Street - Live From Paris']
