# %%
import spotipy
import spotipy.util as util
from config import client_id, client_secret
import pandas as pd

# %%
redirect_uri = 'http://localhost:7777/callback'
scope = 'user-top-read'

# %%
token = util.prompt_for_user_token(
                                   scope=scope, 
                                   client_id=client_id,   
                                   client_secret=client_secret,     
                                   redirect_uri=redirect_uri)

# %%
sp = spotipy.Spotify(auth=token)

# %%
top_tracks = sp.current_user_top_tracks(limit=5)

# %%
top_tracks
# Out:
# {'items': [{'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Qp56T7n950O3EGMsSl81D'},
#       'href': 'https://api.spotify.com/v1/artists/1Qp56T7n950O3EGMsSl81D',
#       'id': '1Qp56T7n950O3EGMsSl81D',
#       'name': 'Ghost',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Qp56T7n950O3EGMsSl81D'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6eOWfFjfBPRsAW0ZS4sbaF'},
#     'href': 'https://api.spotify.com/v1/albums/6eOWfFjfBPRsAW0ZS4sbaF',
#     'id': '6eOWfFjfBPRsAW0ZS4sbaF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bef9b0a348ea8dd18a581025',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bef9b0a348ea8dd18a581025',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bef9b0a348ea8dd18a581025',
#       'width': 64}],
#     'name': 'Seven Inches Of Satanic Panic',
#     'release_date': '2019-09-13',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:6eOWfFjfBPRsAW0ZS4sbaF'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Qp56T7n950O3EGMsSl81D'},
#      'href': 'https://api.spotify.com/v1/artists/1Qp56T7n950O3EGMsSl81D',
#      'id': '1Qp56T7n950O3EGMsSl81D',
#      'name': 'Ghost',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Qp56T7n950O3EGMsSl81D'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 244804,
#    'explicit': False,
#    'external_ids': {'isrc': 'USC4R1902750'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2HZLXBOnaSRhXStMLrq9fD'},
#    'href': 'https://api.spotify.com/v1/tracks/2HZLXBOnaSRhXStMLrq9fD',
#    'id': '2HZLXBOnaSRhXStMLrq9fD',
#    'is_local': False,
#    'name': 'Mary On A Cross',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ec4842badfe3c78c81f2a26433a9cbcbd1278d57?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:2HZLXBOnaSRhXStMLrq9fD'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EPJlUEBy49EX1wuFOvtjK'},
#       'href': 'https://api.spotify.com/v1/artists/4EPJlUEBy49EX1wuFOvtjK',
#       'id': '4EPJlUEBy49EX1wuFOvtjK',
#       'name': 'Becky Hill',
#       'type': 'artist',
#       'uri': 'spotify:artist:4EPJlUEBy49EX1wuFOvtjK'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Cs0zKBU1kc0i8ypK3B9ai'},
#       'href': 'https://api.spotify.com/v1/artists/1Cs0zKBU1kc0i8ypK3B9ai',
#       'id': '1Cs0zKBU1kc0i8ypK3B9ai',
#       'name': 'David Guetta',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6DHfD3rZapWFmEKX1FNNZF'},
#     'href': 'https://api.spotify.com/v1/albums/6DHfD3rZapWFmEKX1FNNZF',
#     'id': '6DHfD3rZapWFmEKX1FNNZF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fe3a09ccabe5f5e6646f7512',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fe3a09ccabe5f5e6646f7512',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fe3a09ccabe5f5e6646f7512',
#       'width': 64}],
#     'name': 'Remember',
#     'release_date': '2021-06-18',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6DHfD3rZapWFmEKX1FNNZF'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EPJlUEBy49EX1wuFOvtjK'},
#      'href': 'https://api.spotify.com/v1/artists/4EPJlUEBy49EX1wuFOvtjK',
#      'id': '4EPJlUEBy49EX1wuFOvtjK',
#      'name': 'Becky Hill',
#      'type': 'artist',
#      'uri': 'spotify:artist:4EPJlUEBy49EX1wuFOvtjK'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Cs0zKBU1kc0i8ypK3B9ai'},
#      'href': 'https://api.spotify.com/v1/artists/1Cs0zKBU1kc0i8ypK3B9ai',
#      'id': '1Cs0zKBU1kc0i8ypK3B9ai',
#      'name': 'David Guetta',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 160766,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM72102420'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4laAKIq9ZxBCwf99rauPYb'},
#    'href': 'https://api.spotify.com/v1/tracks/4laAKIq9ZxBCwf99rauPYb',
#    'id': '4laAKIq9ZxBCwf99rauPYb',
#    'is_local': False,
#    'name': 'Remember',
#    'popularity': 75,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1304cc66e1c0ad738b8258c47df97c0e6aca3bbe?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4laAKIq9ZxBCwf99rauPYb'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4cWyHZZF6764fNSMnEkYdk'},
#       'href': 'https://api.spotify.com/v1/artists/4cWyHZZF6764fNSMnEkYdk',
#       'id': '4cWyHZZF6764fNSMnEkYdk',
#       'name': 'BIZZY',
#       'type': 'artist',
#       'uri': 'spotify:artist:4cWyHZZF6764fNSMnEkYdk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7I00x5cxjEpvjhCeMIYqtv'},
#     'href': 'https://api.spotify.com/v1/albums/7I00x5cxjEpvjhCeMIYqtv',
#     'id': '7I00x5cxjEpvjhCeMIYqtv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738f104fd9e7d6c6e90fea71ea',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028f104fd9e7d6c6e90fea71ea',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518f104fd9e7d6c6e90fea71ea',
#       'width': 64}],
#     'name': 'Anybody',
#     'release_date': '2022-05-13',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7I00x5cxjEpvjhCeMIYqtv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4cWyHZZF6764fNSMnEkYdk'},
#      'href': 'https://api.spotify.com/v1/artists/4cWyHZZF6764fNSMnEkYdk',
#      'id': '4cWyHZZF6764fNSMnEkYdk',
#      'name': 'BIZZY',
#      'type': 'artist',
#      'uri': 'spotify:artist:4cWyHZZF6764fNSMnEkYdk'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 206462,
#    'explicit': False,
#    'external_ids': {'isrc': 'USLZJ2250600'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5hmagJmSC6n4UwT0crJIeC'},
#    'href': 'https://api.spotify.com/v1/tracks/5hmagJmSC6n4UwT0crJIeC',
#    'id': '5hmagJmSC6n4UwT0crJIeC',
#    'is_local': False,
#    'name': 'Anybody',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/58ea5a9f3a08074253db0103621ed16f9345aeca?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5hmagJmSC6n4UwT0crJIeC'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2W8yFh0Ga6Yf3jiayVxwkE'},
#       'href': 'https://api.spotify.com/v1/artists/2W8yFh0Ga6Yf3jiayVxwkE',
#       'id': '2W8yFh0Ga6Yf3jiayVxwkE',
#       'name': 'Dove Cameron',
#       'type': 'artist',
#       'uri': 'spotify:artist:2W8yFh0Ga6Yf3jiayVxwkE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7HWnZ3HvfiVjEIyFWC4Qlf'},
#     'href': 'https://api.spotify.com/v1/albums/7HWnZ3HvfiVjEIyFWC4Qlf',
#     'id': '7HWnZ3HvfiVjEIyFWC4Qlf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b5a28daad91ab7e092b0bf81',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b5a28daad91ab7e092b0bf81',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b5a28daad91ab7e092b0bf81',
#       'width': 64}],
#     'name': 'Breakfast',
#     'release_date': '2022-06-24',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7HWnZ3HvfiVjEIyFWC4Qlf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2W8yFh0Ga6Yf3jiayVxwkE'},
#      'href': 'https://api.spotify.com/v1/artists/2W8yFh0Ga6Yf3jiayVxwkE',
#      'id': '2W8yFh0Ga6Yf3jiayVxwkE',
#      'name': 'Dove Cameron',
#      'type': 'artist',
#      'uri': 'spotify:artist:2W8yFh0Ga6Yf3jiayVxwkE'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 148470,
#    'explicit': False,
#    'external_ids': {'isrc': 'USQX92202196'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6GUiIbJ834FcHewby3PwV0'},
#    'href': 'https://api.spotify.com/v1/tracks/6GUiIbJ834FcHewby3PwV0',
#    'id': '6GUiIbJ834FcHewby3PwV0',
#    'is_local': False,
#    'name': 'Breakfast',
#    'popularity': 72,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a083970d802a02d5c9a78ce1a34138a3fb0b122f?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6GUiIbJ834FcHewby3PwV0'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3lS1y25WAhcqJDATJK70Mq'},
#     'href': 'https://api.spotify.com/v1/albums/3lS1y25WAhcqJDATJK70Mq',
#     'id': '3lS1y25WAhcqJDATJK70Mq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e0b60c608586d88252b8fbc0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e0b60c608586d88252b8fbc0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e0b60c608586d88252b8fbc0',
#       'width': 64}],
#     'name': 'Midnights (3am Edition)',
#     'release_date': '2022-10-22',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:3lS1y25WAhcqJDATJK70Mq'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 260361,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12207556'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0aV5uARAknQgYhBaK944FP'},
#    'href': 'https://api.spotify.com/v1/tracks/0aV5uARAknQgYhBaK944FP',
#    'id': '0aV5uARAknQgYhBaK944FP',
#    'is_local': False,
#    'name': "Would've, Could've, Should've",
#    'popularity': 77,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6c8ca1734a9f8ae7f45f8b0cdaf9429d7cc6f30d?cid=44241990678a457fac9fd0654a4f6a30',
#    'track_number': 19,
#    'type': 'track',
#    'uri': 'spotify:track:0aV5uARAknQgYhBaK944FP'}],
#  'total': 50,
#  'limit': 5,
#  'offset': 0,
#  'href': 'https://api.spotify.com/v1/me/top/tracks?limit=5&offset=0',
#  'next': 'https://api.spotify.com/v1/me/top/tracks?limit=5&offset=5',
#  'previous': None}

# %%
#getting the id of a song
top_tracks["items"][0]["id"]
# Out:
# '2HZLXBOnaSRhXStMLrq9fD'

# %%
#putting the name of a song in the list
top_songs =[]
for idx, item in enumerate(top_tracks['items']):
    top_songs.append(item['id'])

# %%
#viewing list of top 5 songs 
top_songs
# Out:
# ['2HZLXBOnaSRhXStMLrq9fD',
#  '4laAKIq9ZxBCwf99rauPYb',
#  '5hmagJmSC6n4UwT0crJIeC',
#  '6GUiIbJ834FcHewby3PwV0',
#  '0aV5uARAknQgYhBaK944FP']

# %%
#getting audio features of those top 5 songs
features = []
for id in top_songs:
    features.append(sp.audio_features(id))

# %%
#viewing features
features
# Out:
# [[{'danceability': 0.466,
#    'energy': 0.9,
#    'key': 11,
#    'loudness': -4.469,
#    'mode': 1,
#    'speechiness': 0.0447,
#    'acousticness': 0.000235,
#    'instrumentalness': 0.00104,
#    'liveness': 0.103,
#    'valence': 0.561,
#    'tempo': 130.02,
#    'type': 'audio_features',
#    'id': '2HZLXBOnaSRhXStMLrq9fD',
#    'uri': 'spotify:track:2HZLXBOnaSRhXStMLrq9fD',
#    'track_href': 'https://api.spotify.com/v1/tracks/2HZLXBOnaSRhXStMLrq9fD',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2HZLXBOnaSRhXStMLrq9fD',
#    'duration_ms': 244804,
#    'time_signature': 4}],
#  [{'danceability': 0.612,
#    'energy': 0.862,
#    'key': 8,
#    'loudness': -2.903,
#    'mode': 1,
#    'speechiness': 0.037,
#    'acousticness': 0.041,
#    'instrumentalness': 0,
#    'liveness': 0.0907,
#    'valence': 0.354,
#    'tempo': 123.849,
#    'type': 'audio_features',
#    'id': '4laAKIq9ZxBCwf99rauPYb',
#    'uri': 'spotify:track:4laAKIq9ZxBCwf99rauPYb',
#    'track_href': 'https://api.spotify.com/v1/tracks/4laAKIq9ZxBCwf99rauPYb',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4laAKIq9ZxBCwf99rauPYb',
#    'duration_ms': 160766,
#    'time_signature': 4}],
#  [{'danceability': 0.744,
#    'energy': 0.579,
#    'key': 4,
#    'loudness': -5.67,
#    'mode': 1,
#    'speechiness': 0.0813,
#    'acousticness': 0.281,
#    'instrumentalness': 0,
#    'liveness': 0.214,
#    'valence': 0.688,
#    'tempo': 106.173,
#    'type': 'audio_features',
#    'id': '5hmagJmSC6n4UwT0crJIeC',
#    'uri': 'spotify:track:5hmagJmSC6n4UwT0crJIeC',
#    'track_href': 'https://api.spotify.com/v1/tracks/5hmagJmSC6n4UwT0crJIeC',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5hmagJmSC6n4UwT0crJIeC',
#    'duration_ms': 206462,
#    'time_signature': 4}],
#  [{'danceability': 0.64,
#    'energy': 0.553,
#    'key': 2,
#    'loudness': -6.42,
#    'mode': 0,
#    'speechiness': 0.0411,
#    'acousticness': 0.0579,
#    'instrumentalness': 0,
#    'liveness': 0.0914,
#    'valence': 0.486,
#    'tempo': 81.992,
#    'type': 'audio_features',
#    'id': '6GUiIbJ834FcHewby3PwV0',
#    'uri': 'spotify:track:6GUiIbJ834FcHewby3PwV0',
#    'track_href': 'https://api.spotify.com/v1/tracks/6GUiIbJ834FcHewby3PwV0',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6GUiIbJ834FcHewby3PwV0',
#    'duration_ms': 148471,
#    'time_signature': 4}],
#  [{'danceability': 0.483,
#    'energy': 0.84,
#    'key': 7,
#    'loudness': -6.508,
#    'mode': 1,
#    'speechiness': 0.119,
#    'acousticness': 0.43,
#    'instrumentalness': 0.000575,
#    'liveness': 0.146,
#    'valence': 0.55,
#    'tempo': 157.979,
#    'type': 'audio_features',
#    'id': '0aV5uARAknQgYhBaK944FP',
#    'uri': 'spotify:track:0aV5uARAknQgYhBaK944FP',
#    'track_href': 'https://api.spotify.com/v1/tracks/0aV5uARAknQgYhBaK944FP',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0aV5uARAknQgYhBaK944FP',
#    'duration_ms': 260362,
#    'time_signature': 4}]]

# %%
#count of top songs
song_count = len(top_songs)
song_count
# Out:
# 5

# %%
#setting empty list for all the song features
dance = []
energy = []
key = []
loud = []
mode = []
speech = []
acoustic = []
instrument = []
liveness = []
valence = []
tempo = []

# %%
#adding all the features from the JSON to the list
for i in range(song_count):
    dance.append(features[i][0]["danceability"])
    energy.append(features[i][0]["energy"])
    key.append(features[i][0]["key"])
    loud.append(features[i][0]["loudness"])
    mode.append(features[i][0]["mode"])
    speech.append(features[i][0]["speechiness"])
    acoustic.append(features[i][0]["acousticness"])
    instrument.append(features[i][0]["instrumentalness"])
    liveness.append(features[i][0]["liveness"])
    valence.append(features[i][0]["valence"])
    tempo.append(features[i][0]["tempo"])

# %%
#create dictionary from list
song_dict = dict(danceability=dance, 
                 energy =energy,
                 key =key,
                 loudness=loud,
                 mode=mode,
                 speechiness=speech,
                 acousticness=acoustic,
                 instrumentalness=instrument,
                 liveness=liveness,
                 valence=valence,
                 tempo=tempo)

# %%
#putting dictionary in a dataframe
song_df = pd.DataFrame(song_dict)
song_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.466   0.900   11    -4.469     1       0.0447      0.000235
# 1         0.612   0.862    8    -2.903     1       0.0370      0.041000
# 2         0.744   0.579    4    -5.670     1       0.0813      0.281000
# 3         0.640   0.553    2    -6.420     0       0.0411      0.057900
# 4         0.483   0.840    7    -6.508     1       0.1190      0.430000
#
#    instrumentalness  liveness  valence    tempo
# 0          0.001040    0.1030    0.561  130.020
# 1          0.000000    0.0907    0.354  123.849
# 2          0.000000    0.2140    0.688  106.173
# 3          0.000000    0.0914    0.486   81.992
# 4          0.000575    0.1460    0.550  157.979

# %%
top_songs_means = song_df[["danceability","energy","key","loudness",
      "mode","speechiness","acousticness",
      "instrumentalness","liveness","valence","tempo"]].mean()

# %%
top_mean = top_songs_means.mean()

# %%
ts_mean = 11.800125012121212
fr_mean = 12.051548975419582
sp_mean = 12.964633383051945
rd_mean = 11.325443456060606
e9_mean = 11.426378996083917
rp_mean = 11.37416730771717
lv_mean = 10.85594381328283
fk_mean = 10.274035654943182
ev_mean = 10.558981043212121
md_mean = 10.680990369545453

# %%
df_data = {'Albums': ["Taylor Swift",
                      "Fearless Taylor's Version",
                      "Speak Now", 
                      "Red Taylor's Verison",
                      "1989", 
                      "Reputation",
                      "Lover",
                      "Folklore",
                      "Evermore", 
                      "Midnights 3AM"],
           'Means': [ts_mean, 
                     fr_mean,
                     sp_mean,
                     rd_mean,
                     e9_mean,
                     rp_mean,
                     lv_mean,
                     fk_mean,
                     ev_mean,
                     md_mean]}

df = pd.DataFrame(data=df_data)
df
# Out:
#                       Albums      Means
# 0               Taylor Swift  11.800125
# 1  Fearless Taylor's Version  12.051549
# 2                  Speak Now  12.964633
# 3       Red Taylor's Verison  11.325443
# 4                       1989  11.426379
# 5                 Reputation  11.374167
# 6                      Lover  10.855944
# 7                   Folklore  10.274036
# 8                   Evermore  10.558981
# 9              Midnights 3AM  10.680990

# %%
df["My Top Mean"] = top_mean

# %%
df
# Out:
#                       Albums      Means  My Top Mean
# 0               Taylor Swift  11.800125    11.293472
# 1  Fearless Taylor's Version  12.051549    11.293472
# 2                  Speak Now  12.964633    11.293472
# 3       Red Taylor's Verison  11.325443    11.293472
# 4                       1989  11.426379    11.293472
# 5                 Reputation  11.374167    11.293472
# 6                      Lover  10.855944    11.293472
# 7                   Folklore  10.274036    11.293472
# 8                   Evermore  10.558981    11.293472
# 9              Midnights 3AM  10.680990    11.293472

# %%
df.dtypes
# Out:
# Albums          object
# Means          float64
# My Top Mean    float64
# dtype: object

# %%
df["Difference"] = df["Means"] - df["My Top Mean"]

# %%
df
# Out:
#                       Albums      Means  My Top Mean  Difference
# 0               Taylor Swift  11.800125    11.293472    0.506653
# 1  Fearless Taylor's Version  12.051549    11.293472    0.758077
# 2                  Speak Now  12.964633    11.293472    1.671162
# 3       Red Taylor's Verison  11.325443    11.293472    0.031972
# 4                       1989  11.426379    11.293472    0.132907
# 5                 Reputation  11.374167    11.293472    0.080695
# 6                      Lover  10.855944    11.293472   -0.437528
# 7                   Folklore  10.274036    11.293472   -1.019436
# 8                   Evermore  10.558981    11.293472   -0.734491
# 9              Midnights 3AM  10.680990    11.293472   -0.612481

# %%
df["Minimum"] = df["Difference"].abs()

# %%
df
# Out:
#                       Albums      Means  My Top Mean  Difference   Minimum
# 0               Taylor Swift  11.800125    11.293472    0.506653  0.506653
# 1  Fearless Taylor's Version  12.051549    11.293472    0.758077  0.758077
# 2                  Speak Now  12.964633    11.293472    1.671162  1.671162
# 3       Red Taylor's Verison  11.325443    11.293472    0.031972  0.031972
# 4                       1989  11.426379    11.293472    0.132907  0.132907
# 5                 Reputation  11.374167    11.293472    0.080695  0.080695
# 6                      Lover  10.855944    11.293472   -0.437528  0.437528
# 7                   Folklore  10.274036    11.293472   -1.019436  1.019436
# 8                   Evermore  10.558981    11.293472   -0.734491  0.734491
# 9              Midnights 3AM  10.680990    11.293472   -0.612481  0.612481

# %%
df.nsmallest(1, 'Minimum')
# Out:
#                  Albums      Means  My Top Mean  Difference   Minimum
# 3  Red Taylor's Verison  11.325443    11.293472    0.031972  0.031972
